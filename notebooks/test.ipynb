# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('E:/All Project/salary_prediction/data/raw/web_data.csv')

# %%
df.head()
# Out:
#   company_names                                              allas  \
# 0           TCS  1.1L Reviews9.8L Salaries11.8k Interviews2.2k ...
# 1     Accenture  71.3k Reviews6.5L Salaries9.2k Interviews42k J...
# 2         Wipro  63.5k Reviews4.8L Salaries6.7k Interviews5.8k ...
# 3     Cognizant  59.8k Reviews6L Salaries6.3k Interviews751 Job...
# 4     Capgemini  51.5k Reviews4.8L Salaries5.4k Interviews1.9k ...
#
#    company_reviews
# 0              3.3
# 1              3.7
# 2              3.6
# 3              3.6
# 4              3.7

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [company_names, allas, company_reviews]
# Index: []

# %%
df.drop_duplicates(inplace=True)

# %%
def drop_duplicates(data):
    df = data.drop_duplicates(inplace=True)
    return df

# %%
df.head()
# Out:
#   company_names                                              allas  \
# 0           TCS  1.1L Reviews9.7L Salaries11.8k Interviews1.8k ...
# 1     Accenture  71.2k Reviews6.5L Salaries9.1k Interviews30.9k...
# 2         Wipro  63.5k Reviews4.8L Salaries6.6k Interviews7.8k ...
# 3     Cognizant  59.8k Reviews6L Salaries6.3k Interviews674 Job...
# 4     Capgemini  51.3k Reviews4.7L Salaries5.4k Interviews1.8k ...
#
#    company_reviews
# 0              3.3
# 1              3.7
# 2              3.6
# 3              3.6
# 4              3.7

# %%
df['allas'][0]
# Out:
# '1.1L Reviews9.8L Salaries11.8k Interviews2.2k Jobs10.6k Benefits93 Photos'

# %%
df['allas'].str.split(' ')[0]
# Out:
# ['1.1L',
#  'Reviews9.8L',
#  'Salaries11.8k',
#  'Interviews2.2k',
#  'Jobs10.6k',
#  'Benefits93',
#  'Photos']

# %%
Reviews = df['allas'].str.split('Reviews').str[0]
Salaries =df['allas'].str.split(' ').str[1].str.split('Reviews').str[1]
Interviews = df['allas'].str.split(' ').str[2].str.split('Salaries').str[1]
jobs = df['allas'].str.split(' ').str[3].str.split('Interviews').str[1]
Benefits = df['allas'].str.split(' ').str[4].str.split('Jobs').str[1]
photos = df['allas'].str.split(' ').str[5].str.split('Benefits').str[1]

# %%
def data_corect(df):
    df['Reviews'] = df['allas'].str.split('Reviews').str[0]
    df['Salaries'] = df['allas'].str.split(' ').str[1].str.split('Reviews').str[1]
    df['Interviews'] = df['allas'].str.split(' ').str[2].str.split('Salaries').str[1]
    df['jobs'] = df['allas'].str.split(' ').str[3].str.split('Interviews').str[1]
    df['Benefits'] = df['allas'].str.split(' ').str[4].str.split('Jobs').str[1]
    df['photos'] = df['allas'].str.split(' ').str[5].str.split('Benefits').str[1]
    df.drop(columns='allas',inplace=True)

    return df

# %%
data_corect(df)
# Out:
#                              company_names  company_reviews Reviews Salaries  \
# 0                                      TCS              3.3   1.1L      9.8L
# 1                                Accenture              3.7  71.3k      6.5L
# 2                                    Wipro              3.6  63.5k      4.8L
# 3                                Cognizant              3.6  59.8k        6L
# 4                                Capgemini              3.7  51.5k      4.8L
# ...                                    ...              ...     ...      ...
# 9955                      Brightsun Travel              2.8    107       479
# 9956  Swami Vivekanand Subharti University              3.7    107       292
# 9957                    The AEC Associates              4.5    107       187
# 9958                            Shindengen              3.8    107       572
# 9959                               Sherweb              3.0    108       213
#
#      Interviews  jobs Benefits photos
# ...

# %%
df = pd.read_csv('E:/All Project/salary_prediction/data/harf_prose/train.csv')

# %%
df.head()
# Out:
#                   company_names  company_reviews Reviews Salaries Interviews  \
# 0            Innominds Software              3.3    544      4.5k         48
# 1                 Rimini Street              4.0    182       895          8
# 2      Springer Nature in India              4.0    323      2.5k         40
# 3                 Park Hospital              3.7    385      1.3k         26
# 4  Eduquity Career Technologies              3.4    108       513          8
#
#   jobs Benefits photos
# 0   34       31      6
# 1   18       15      1
# 2   12       25     25
# 3   12       12     --
# 4   --        4     --

# %%
df[df['company_names']=='TCS']
# Out:
# Empty DataFrame
# Columns: [company_names, company_reviews, Reviews, Salaries, Interviews, jobs, Benefits, photos]
# Index: []

# %%
df['company_names'].value_counts()
# Out:
# company_names
# Innominds Software                    1
# TravelTriangle                        1
# Utthunga Technologies                 1
# JK Paper                              1
# Rainbow Childrens Hospital            1
#                                      ..
# AachiGroup                            1
# Tokai Imperial Rubber India           1
# NuSummit                              1
# Sandberg Translation Partners         1
# Bihar Foundry and Castings Limited    1
# Name: count, Length: 7606, dtype: int64

# %%
df.head()
# Out:
#                   company_names  company_reviews Reviews Salaries Interviews  \
# 0            Innominds Software              3.3    544      4.5k         48
# 1                 Rimini Street              4.0    182       895          8
# 2      Springer Nature in India              4.0    323      2.5k         40
# 3                 Park Hospital              3.7    385      1.3k         26
# 4  Eduquity Career Technologies              3.4    108       513          8
#
#   jobs Benefits photos
# 0   34       31      6
# 1   18       15      1
# 2   12       25     25
# 3   12       12     --
# 4   --        4     --

# %%
df.drop(columns='company_names',inplace=True)

# %%
df.head()
# Out:
#    company_reviews Reviews Salaries Interviews jobs Benefits photos
# 0              3.3    544      4.5k         48   34       31      6
# 1              4.0    182       895          8   18       15      1
# 2              4.0    323      2.5k         40   12       25     25
# 3              3.7    385      1.3k         26   12       12     --
# 4              3.4    108       513          8   --        4     --

# %%
df['company_reviews'].value_counts().sort_index()
# Out:
# company_reviews
# 1.0      1
# 1.3      1
# 1.5      1
# 1.7      1
# 1.8      1
# 1.9      3
# 2.0      2
# 2.1      4
# 2.2      5
# 2.3      7
# 2.4     14
# 2.5     18
# 2.6     32
# 2.7     44
# 2.8     64
# 2.9     95
# 3.0    136
# 3.1    184
# 3.2    282
# 3.3    356
# 3.4    429
# 3.5    525
# 3.6    635
# 3.7    756
# 3.8    805
# 3.9    807
# 4.0    723
# 4.1    619
# 4.2    423
# 4.3    232
# 4.4    172
# 4.5     88
# 4.6     60
# 4.7     34
# 4.8     30
# 4.9     16
# Name: count, dtype: int64

# %%
a = []
for i in df['company_reviews']:
    if i > 4:
        a.append('excellent')
    elif i < 4 and i > 3:
        a.append('good')
    else:
        a.append('Poor')

# %%
pd.DataFrame(a).value_counts()
# Out:
# 0
# good         4779
# excellent    1674
# Poor         1153
# Name: count, dtype: int64

# %%
df['company_reviews'].value_counts()
# Out:
# company_reviews
# 3.9    807
# 3.8    805
# 3.7    756
# 4.0    723
# 3.6    635
# 4.1    619
# 3.5    525
# 3.4    429
# 4.2    423
# 3.3    356
# 3.2    282
# 4.3    232
# 3.1    184
# 4.4    172
# 3.0    136
# 2.9     95
# 4.5     88
# 2.8     64
# 4.6     60
# 2.7     44
# 4.7     34
# 2.6     32
# 4.8     30
# 2.5     18
# 4.9     16
# 2.4     14
# 2.3      7
# 2.2      5
# 2.1      4
# 1.9      3
# 2.0      2
# 1.7      1
# 1.5      1
# 1.0      1
# 1.3      1
# 1.8      1
# Name: count, dtype: int64

# %%
# change compay reviews in to catogorical data
def change_into_cat(df):
    a = []
    for i in df['company_reviews']:
        if i > 4:
            a.append('excellent')
        elif i < 4 and i > 3:
            a.append('good')
        else:
            a.append('Poor') 
    df['company_reviews'] = a

    return df

# %%
df = change_into_cat(df)

# %%
df.head()
# Out:
#   company_reviews Reviews Salaries Interviews jobs Benefits photos
# 0            good    544      4.5k         48   34       31      6
# 1            Poor    182       895          8   18       15      1
# 2            Poor    323      2.5k         40   12       25     25
# 3            good    385      1.3k         26   12       12     --
# 4            good    108       513          8   --        4     --

# %%
df['Reviews'].unique()
# Out:
# array(['544 ', '182 ', '323 ', '385 ', '108 ', '230 ', '146 ', '198 ',
#        '115 ', '148 ', '905 ', '570 ', '145 ', '405 ', '186 ', '139 ',
#        '174 ', '143 ', '151 ', '667 ', '4.2k ', '165 ', '267 ', '223 ',
#        '11.7k ', '498 ', '133 ', '164 ', '167 ', '109 ', '204 ', '141 ',
#        '124 ', '577 ', '206 ', '497 ', '245 ', '119 ', '123 ', '113 ',
#        '370 ', '479 ', '235 ', '1.2k ', '324 ', '175 ', '352 ', '1.8k ',
#        '2k ', '281 ', '195 ', '274 ', '7.6k ', '163 ', '134 ', '355 ',
#        '2.5k ', '326 ', '161 ', '262 ', '483 ', '372 ', '118 ', '194 ',
#        '137 ', '264 ', '121 ', '375 ', '368 ', '176 ', '110 ', '201 ',
#        '213 ', '2.6k ', '166 ', '156 ', '301 ', '344 ', '116 ', '358 ',
#        '547 ', '307 ', '138 ', '350 ', '604 ', '171 ', '962 ', '183 ',
#        '825 ', '111 ', '205 ', '180 ', '357 ', '193 ', '178 ', '202 ',
#        '208 ', '7.4k ', '562 ', '160 ', '226 ', '179 ', '131 ', '127 ',
# ...

# %%
a = ['434 ', '147 ', '340 ', '108 ', '1.5k ', '140 ', '112 ', '241 ',
       '248 ', '324 ', '1.8k ', '161 ', '1.1k ', '143 ', '123 ', '182 ',
       '111 ', '220 ', '302 ', '303 ', '242 ', '158 ', '576 ', '448 ',
       '488 ', '348 ', '213 ', '526 ', '157 ', '258 ', '118 ', '685 ']

# %%
for i in a:
    
    print(i)
    print(i[-1])
# Out:
# 434
#
# 147
#
# 340
#
# 108
#
# 1.5k
#
# 140
#
# 112
#
# 241
#
# 248
#
# 324
#
# 1.8k
#
# 161
#
# 1.1k
#
# 143
#
# 123
#
# 182
#
# 111
#
# 220
#
# 302
#
# 303
#
# 242
#
# 158
#
# 576
#
# 448
#
# 488
#
# 348
#
# 213
#
# 526
#
# 157
#
# 258
#
# 118
#
# 685

# %%
df['Reviews'].str.replace('k','').unique()
# Out:
# array(['544 ', '182 ', '323 ', '385 ', '108 ', '230 ', '146 ', '198 ',
#        '115 ', '148 ', '905 ', '570 ', '145 ', '405 ', '186 ', '139 ',
#        '174 ', '143 ', '151 ', '667 ', '4.2 ', '165 ', '267 ', '223 ',
#        '11.7 ', '498 ', '133 ', '164 ', '167 ', '109 ', '204 ', '141 ',
#        '124 ', '577 ', '206 ', '497 ', '245 ', '119 ', '123 ', '113 ',
#        '370 ', '479 ', '235 ', '1.2 ', '324 ', '175 ', '352 ', '1.8 ',
#        '2 ', '281 ', '195 ', '274 ', '7.6 ', '163 ', '134 ', '355 ',
#        '2.5 ', '326 ', '161 ', '262 ', '483 ', '372 ', '118 ', '194 ',
#        '137 ', '264 ', '121 ', '375 ', '368 ', '176 ', '110 ', '201 ',
#        '213 ', '2.6 ', '166 ', '156 ', '301 ', '344 ', '116 ', '358 ',
#        '547 ', '307 ', '138 ', '350 ', '604 ', '171 ', '962 ', '183 ',
#        '825 ', '111 ', '205 ', '180 ', '357 ', '193 ', '178 ', '202 ',
#        '208 ', '7.4 ', '562 ', '160 ', '226 ', '179 ', '131 ', '127 ',
# ...

# %%
def remove_car(df: str) -> pd.DataFrame:
    df['Reviews'] = df['Reviews'].str.replace('k','')
    df['Reviews'] = df['Reviews'].str.replace('L','')
    df['Reviews'] = df['Reviews'].str.replace('--','')
    df['Reviews'] = df['Reviews'].str.replace(' ','0')
    df['Reviews'] = df['Reviews'].astype(float)
    return df

# %%
df.head()
# Out:
#   company_reviews Reviews Salaries Interviews jobs Benefits photos
# 0            good    544      4.5k         48   34       31      6
# 1            Poor    182       895          8   18       15      1
# 2            Poor    323      2.5k         40   12       25     25
# 3            good    385      1.3k         26   12       12     --
# 4            good    108       513          8   --        4     --

# %%
df['company_reviews'].value_counts()
# Out:
# company_reviews
# good         4779
# excellent    1674
# Poor         1153
# Name: count, dtype: int64

# %%
import pandas as pd

# %%
a = remove_car(df=df)

# %%
df[df['Reviews']==' ']
# Out:
# Empty DataFrame
# Columns: [company_reviews, Reviews, Salaries, Interviews, jobs, Benefits, photos]
# Index: []

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7606 entries, 0 to 7605
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   company_reviews  7606 non-null   object
#  1   Reviews          7606 non-null   float64
#  2   Salaries         7606 non-null   object
#  3   Interviews       7606 non-null   object
#  4   jobs             7606 non-null   object
#  5   Benefits         7606 non-null   object
#  6   photos           7606 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 416.1+ KB

# %%
def astype(df: pd.DataFrame) -> pd.DataFrame:
    df['Reviews'] = df['Reviews'].astype(float)
    return df

# %%
a = astype(a)

# %%
df['Salaries'].unique()
# Out:
# array(['4.5k', '895', '2.5k', ..., '21k', '55', '1'], dtype=object)

# %%
b = []

for i in a['Salaries']:
    if 'k' in i:
        n = i.replace('k','')
        n = float(n)
        n = n * 1000
        b.append(n)
    elif 'L' in i:
        n = i.replace('L','')
        n = float(n)
        n = n * 100000
        b.append(n)
    else:
        b.append(i)

# %%
def replace_salary_car(df: pd.DataFrame) -> pd.DataFrame:
    b = []

    for i in df['Salaries']:
        if 'k' in i:
            n = i.replace('k','')
            n = float(n)
            n = n * 1000
            b.append(n)
        elif 'L' in i:
            n = i.replace('L','')
            n = float(n)
            n = n * 100000
            b.append(n)
        elif '--' in i:
            n = i.replace('--','0')
            n = float(n)
            n = n * 100000
            b.append(n)
        else:
            b.append(i)
    df['Salaries'] = b
    df['Salaries'] = df.drop(index=952)['Salaries'].astype(float)
    return df

# %%
y = replace_salary_car(df=df)

# %%
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7606 entries, 0 to 7605
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   company_reviews  7606 non-null   object
#  1   Reviews          7606 non-null   float64
#  2   Salaries         7605 non-null   float64
#  3   Interviews       7606 non-null   object
#  4   jobs             7606 non-null   object
#  5   Benefits         7606 non-null   object
#  6   photos           7606 non-null   object
# dtypes: float64(2), object(5)
# memory usage: 416.1+ KB

# %%
pd.DataFrame(b)[0].unique()
# Out:
# array([4500.0, '895', 2500.0, ..., 21000.0, '55', '1'], dtype=object)

# %%
df.drop(index=952)['Salaries'].astype(float)
# Out:
# 0       4500.0
# 1        895.0
# 2       2500.0
# 3       1300.0
# 4        513.0
#          ...
# 7601     516.0
# 7602     517.0
# 7603    1200.0
# 7604    4500.0
# 7605     304.0
# Name: Salaries, Length: 7605, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7606 entries, 0 to 7605
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   company_reviews  7606 non-null   object
#  1   Reviews          7606 non-null   float64
#  2   Salaries         7605 non-null   float64
#  3   Interviews       7606 non-null   object
#  4   jobs             7606 non-null   object
#  5   Benefits         7606 non-null   object
#  6   photos           7606 non-null   object
# dtypes: float64(2), object(5)
# memory usage: 416.1+ KB

# %%
df.head()
# Out:
#   company_reviews  Reviews  Salaries Interviews jobs Benefits photos
# 0            good   5440.0    4500.0         48   34       31      6
# 1            Poor   1820.0     895.0          8   18       15      1
# 2            Poor   3230.0    2500.0         40   12       25     25
# 3            good   3850.0    1300.0         26   12       12     --
# 4            good   1080.0     513.0          8   --        4     --

# %%
df["Interviews"].unique()
# Out:
# array(['48', '8', '40', '26', '10', '20', '15', '9', '145', '27', '35',
#        '12', '13', '7', '23', '444', '28', '17', '1.1k', '4', '19', '11',
#        '47', '77', '3', '75', '92', '29', '136', '312', '21', '16', '474',
#        '5', '185', '25', '78', '38', '100', '34', '43', '116', '152',
#        '14', '6', '31', '22', '54', '18', '45', '32', '879', '36', '66',
#        '387', '82', '57', '46', '41', '58', '367', '37', '101', '33',
#        '626', '69', '73', '67', '2', '53', '119', '206', '49', '24', '93',
#        '44', '368', '176', '56', '39', '83', '95', '42', '917', '64',
#        '111', '273', '91', '770', '117', '370', '61', '777', '618', '174',
#        '249', '52', '1', '99', '192', '71', '68', '423', '373', '178',
#        '202', '313', '135', '60', '416', '30', '329', '63', '94', '96',
#        '143', '516', '121', '1k', '161', '201', '84', '184', '62', '189',
#        '140', '112', '97', '305', '198', '332', '55', '106', '137', '79',
# ...

# %%
# remove letter in salary columns and change the datatype into float
def replace_Interviews_car(df: pd.DataFrame) -> pd.DataFrame:
    b = []

    for i in df['Interviews']:
        if 'k' in i:
            n = i.replace('k','')
            n = float(n)
            n = n * 1000
            b.append(n)
        elif '--' in i:
            n = i.replace('--','0')
            n = float(n)
            b.append(n)
        else:
            b.append(i)
    df['Interviews'] = b
    df['Interviews'] = df['Interviews'].astype(float)

    return df

# %%
replace_Interviews_car(df=df)
# Out:
#      company_reviews  Reviews  Salaries  Interviews jobs Benefits photos
# 0               good   5440.0    4500.0        48.0   34       31      6
# 1               Poor   1820.0     895.0         8.0   18       15      1
# 2               Poor   3230.0    2500.0        40.0   12       25     25
# 3               good   3850.0    1300.0        26.0   12       12     --
# 4               good   1080.0     513.0         8.0   --        4     --
# ...              ...      ...       ...         ...  ...      ...    ...
# 7601            good   1900.0     516.0        18.0   --       14      1
# 7602            good   2050.0     517.0        21.0    4        7      2
# 7603            good   1980.0    1200.0        16.0   20       13      6
# 7604       excellent      1.2    4500.0        66.0   --       66     20
# 7605       excellent   1460.0     304.0         8.0   --        2      5
#
# [7606 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7606 entries, 0 to 7605
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   company_reviews  7606 non-null   object
#  1   Reviews          7606 non-null   float64
#  2   Salaries         7605 non-null   float64
#  3   Interviews       7606 non-null   float64
#  4   jobs             7606 non-null   object
#  5   Benefits         7606 non-null   object
#  6   photos           7606 non-null   object
# dtypes: float64(3), object(4)
# memory usage: 416.1+ KB

# %%
df.head()
# Out:
#   company_reviews  Reviews  Salaries  Interviews jobs Benefits photos
# 0            good   5440.0    4500.0        48.0   34       31      6
# 1            Poor   1820.0     895.0         8.0   18       15      1
# 2            Poor   3230.0    2500.0        40.0   12       25     25
# 3            good   3850.0    1300.0        26.0   12       12     --
# 4            good   1080.0     513.0         8.0   --        4     --

# %%
df[df['jobs'] == '--']
# Out:
#      company_reviews  Reviews  Salaries  Interviews jobs Benefits photos
# 4               good   1080.0     513.0         8.0   --        4     --
# 5               good   2300.0    1200.0        10.0   --       23     --
# 6               good   1460.0     624.0        20.0   --       10     --
# 8          excellent   1150.0     432.0         9.0   --        1     --
# 9               good   1480.0     590.0         8.0   --       14      2
# ...              ...      ...       ...         ...  ...      ...    ...
# 7597       excellent   1910.0     891.0        16.0   --       12     --
# 7598            good   2400.0     845.0        20.0   --       12      2
# 7601            good   1900.0     516.0        18.0   --       14      1
# 7604       excellent      1.2    4500.0        66.0   --       66     20
# 7605       excellent   1460.0     304.0         8.0   --        2      5
#
# [3083 rows x 7 columns]

# %%
df['jobs'].unique()
# Out:
# array(['34', '18', '12', '--', '5', '14', '3', '134', '2', '74', '4',
#        '21', '11', '1', '7', '10', '27', '8', '56', '804', '6', '26',
#        '111', '13', '37', '9', '23', '38', '29', '370', '53', '25', '66',
#        '164', '98', '33', '91', '16', '175', '107', '15', '142', '85',
#        '22', '28', '105', '31', '20', '52', '30', '86', '36', '405',
#        '726', '40', '94', '64', '49', '19', '17', '44', '547', '90',
#        '117', '131', '76', '136', '95', '212', '39', '283', '132', '62',
#        '41', '35', '75', '123', '43', '152', '104', '48', '84', '288',
#        '50', '93', '116', '268', '83', '220', '71', '156', '527', '51',
#        '42', '149', '351', '243', '24', '189', '295', '79', '118', '63',
#        '215', '207', '54', '58', '32', '77', '69', '170', '188', '65',
#        '128', '222', '216', '68', '1.5k', '106', '306', '138', '224',
#        '45', '221', '47', '150', '799', '401', '202', '88', '137', '214',
# ...

# %%
def replace_jobs_car(df: pd.DataFrame) -> pd.DataFrame:
    b = []

    for i in df['jobs']:
        if 'k' in i:
            n = i.replace('k','')
            n = float(n)
            n = n * 1000
            b.append(n)
        elif '--' in i:
            n = i.replace('--','0')
            n = float(n)
            b.append(n)
        else:
            b.append(i)
    df['jobs'] = b
    df['jobs'] = df['jobs'].astype(float)

    return df

# %%
replace_jobs_car(df=df)
# Out:
#      company_reviews  Reviews  Salaries  Interviews  jobs Benefits photos
# 0               good   5440.0    4500.0        48.0  34.0       31      6
# 1               Poor   1820.0     895.0         8.0  18.0       15      1
# 2               Poor   3230.0    2500.0        40.0  12.0       25     25
# 3               good   3850.0    1300.0        26.0  12.0       12     --
# 4               good   1080.0     513.0         8.0   0.0        4     --
# ...              ...      ...       ...         ...   ...      ...    ...
# 7601            good   1900.0     516.0        18.0   0.0       14      1
# 7602            good   2050.0     517.0        21.0   4.0        7      2
# 7603            good   1980.0    1200.0        16.0  20.0       13      6
# 7604       excellent      1.2    4500.0        66.0   0.0       66     20
# 7605       excellent   1460.0     304.0         8.0   0.0        2      5
#
# [7606 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7606 entries, 0 to 7605
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   company_reviews  7606 non-null   object
#  1   Reviews          7606 non-null   float64
#  2   Salaries         7605 non-null   float64
#  3   Interviews       7606 non-null   float64
#  4   jobs             7606 non-null   float64
#  5   Benefits         7606 non-null   object
#  6   photos           7606 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 416.1+ KB

# %%
df.head()
# Out:
#   company_reviews  Reviews  Salaries  Interviews  jobs Benefits photos
# 0            good   5440.0    4500.0        48.0  34.0       31      6
# 1            Poor   1820.0     895.0         8.0  18.0       15      1
# 2            Poor   3230.0    2500.0        40.0  12.0       25     25
# 3            good   3850.0    1300.0        26.0  12.0       12     --
# 4            good   1080.0     513.0         8.0   0.0        4     --

# %%
df['Benefits'].unique()
# Out:
# array(['31', '15', '25', '12', '4', '23', '10', '3', '1', '14', '129',
#        '47', '11', '27', '9', '20', '84', '199', '1.1k', '38', '22', '8',
#        '16', '37', '33', '21', '19', '17', '7', '39', '5', '87', '6',
#        '26', '122', '163', '625', '2', '40', '132', '13', '29', '192',
#        '24', '73', '18', '205', '50', '44', '46', '34', '113', '98', '28',
#        '64', '94', '57', '45', '--', '49', '212', '66', '444', '143',
#        '42', '53', '43', '63', '83', '348', '60', '32', '62', '68', '115',
#        '54', '154', '315', '180', '103', '86', '200', '110', '51', '516',
#        '74', '30', '749', '105', '148', '55', '968', '35', '345', '614',
#        '41', '520', '227', '257', '297', '183', '114', '48', '755', '317',
#        '396', '579', '139', '151', '276', '80', '93', '70', '107', '261',
#        '190', '88', '397', '58', '101', '120', '158', '147', '432', '240',
#        '97', '81', '221', '128', '52', '623', '79', '77', '135', '102',
# ...

# %%
def replace_Benefits_car(df: pd.DataFrame) -> pd.DataFrame:
    b = []

    for i in df['Benefits']:
        if 'k' in i:
            n = i.replace('k','')
            n = float(n)
            n = n * 1000
            b.append(n)
        elif '--' in i:
            n = i.replace('--','0')
            n = float(n)
            b.append(n)
        else:
            b.append(i)
    df['Benefits'] = b
    df['Benefits'] = df['Benefits'].astype(float)

    return df

# %%
replace_Benefits_car(df=df)
# Out:
#      company_reviews  Reviews  Salaries  Interviews  jobs  Benefits photos
# 0               good   5440.0    4500.0        48.0  34.0      31.0      6
# 1               Poor   1820.0     895.0         8.0  18.0      15.0      1
# 2               Poor   3230.0    2500.0        40.0  12.0      25.0     25
# 3               good   3850.0    1300.0        26.0  12.0      12.0     --
# 4               good   1080.0     513.0         8.0   0.0       4.0     --
# ...              ...      ...       ...         ...   ...       ...    ...
# 7601            good   1900.0     516.0        18.0   0.0      14.0      1
# 7602            good   2050.0     517.0        21.0   4.0       7.0      2
# 7603            good   1980.0    1200.0        16.0  20.0      13.0      6
# 7604       excellent      1.2    4500.0        66.0   0.0      66.0     20
# 7605       excellent   1460.0     304.0         8.0   0.0       2.0      5
#
# [7606 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7606 entries, 0 to 7605
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   company_reviews  7606 non-null   object
#  1   Reviews          7606 non-null   float64
#  2   Salaries         7605 non-null   float64
#  3   Interviews       7606 non-null   float64
#  4   jobs             7606 non-null   float64
#  5   Benefits         7606 non-null   float64
#  6   photos           7606 non-null   object
# dtypes: float64(5), object(2)
# memory usage: 416.1+ KB

# %%
df.head()
# Out:
#   company_reviews  Reviews  Salaries  Interviews  jobs  Benefits photos
# 0            good   5440.0    4500.0        48.0  34.0      31.0      6
# 1            Poor   1820.0     895.0         8.0  18.0      15.0      1
# 2            Poor   3230.0    2500.0        40.0  12.0      25.0     25
# 3            good   3850.0    1300.0        26.0  12.0      12.0     --
# 4            good   1080.0     513.0         8.0   0.0       4.0     --

# %%
df[df['photos'] == '--']
# Out:
#      company_reviews  Reviews  Salaries  Interviews  jobs  Benefits photos
# 3               good   3850.0    1300.0        26.0  12.0      12.0     --
# 4               good   1080.0     513.0         8.0   0.0       4.0     --
# 5               good   2300.0    1200.0        10.0   0.0      23.0     --
# 6               good   1460.0     624.0        20.0   0.0      10.0     --
# 7               good   1980.0     703.0        15.0   5.0       3.0     --
# ...              ...      ...       ...         ...   ...       ...    ...
# 7590       excellent   2100.0     567.0        11.0   0.0      22.0     --
# 7591       excellent   2010.0     890.0        11.0  53.0      25.0     --
# 7596            good   1250.0     480.0         7.0   1.0      16.0     --
# 7597       excellent   1910.0     891.0        16.0   0.0      12.0     --
# 7600            good   1690.0     400.0        12.0   5.0       5.0     --
#
# [4307 rows x 7 columns]

# %%
def replace_photos_car(df: pd.DataFrame) -> pd.DataFrame:
    b = []

    for i in df['photos']:
        if 'k' in i:
            n = i.replace('k','')
            n = float(n)
            n = n * 1000
            b.append(n)
        elif '--' in i:
            n = i.replace('--','0')
            n = float(n)
            b.append(n)
        else:
            b.append(i)
    df['photos'] = b
    df['photos'] = df['photos'].astype(int)

    return df

# %%
replace_photos_car(df=df)
# Out:
#      company_reviews  Reviews  Salaries  Interviews  jobs  Benefits  photos
# 0               good   5440.0    4500.0        48.0  34.0      31.0       6
# 1               Poor   1820.0     895.0         8.0  18.0      15.0       1
# 2               Poor   3230.0    2500.0        40.0  12.0      25.0      25
# 3               good   3850.0    1300.0        26.0  12.0      12.0       0
# 4               good   1080.0     513.0         8.0   0.0       4.0       0
# ...              ...      ...       ...         ...   ...       ...     ...
# 7601            good   1900.0     516.0        18.0   0.0      14.0       1
# 7602            good   2050.0     517.0        21.0   4.0       7.0       2
# 7603            good   1980.0    1200.0        16.0  20.0      13.0       6
# 7604       excellent      1.2    4500.0        66.0   0.0      66.0      20
# 7605       excellent   1460.0     304.0         8.0   0.0       2.0       5
#
# [7606 rows x 7 columns]

# %%
df['photos'].value_counts()
# Out:
# photos
# 0      4307
# 1       735
# 2       389
# 3       271
# 4       227
#        ...
# 416       1
# 55        1
# 126       1
# 139       1
# 75        1
# Name: count, Length: 109, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
df.dropna(inplace=True)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.drop(columns='Salaries'),df['Salaries'], test_size=0.2, random_state=42)

# %%
X_train.head()
# Out:
#      company_reviews  Reviews  Interviews  jobs  Benefits  photos
# 4049            good   2070.0        14.0   1.0      24.0       0
# 1635            good   2250.0         7.0  15.0      22.0       0
# 4992            good   1690.0         7.0   0.0       9.0       0
# 6203            good   1170.0        11.0   0.0       8.0       4
# 4903            good   3160.0        16.0   0.0      26.0       0

# %%
from sklearn.preprocessing import OneHotEncoder
one  = OneHotEncoder(drop='first',sparse_output=False)

# %%
one.fit(X_train[['company_reviews']])
train = one.transform(X_train[['company_reviews']])
test = one.transform(X_test[['company_reviews']])

# %%
from sklearn.compose import ColumnTransformer

# %%
t = ColumnTransformer(transformers=[
    ('Oneh',one,[0]),
], remainder='passthrough')

# %%
def columns_transormers(df: pd.DataFrame) -> pd.DataFrame:
    col = ColumnTransformer(transformers=[

        ('Oneh',one,[0]),
    ], remainder='passthrough')
    new_df = col.fit_transform(df)
    new_df = pd.DataFrame(new_df,columns=col.get_feature_names_out())
    return new_df

# %%
t.fit(X_train)
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('Oneh',
#                                  OneHotEncoder(drop='first',
#                                                sparse_output=False),
#                                  [0])])

# %%
pd.DataFrame(t.transform(X_train),columns=t.get_feature_names_out())
# Out:
#       Oneh__company_reviews_excellent  Oneh__company_reviews_good  \
# 0                                 0.0                         1.0
# 1                                 0.0                         1.0
# 2                                 0.0                         1.0
# 3                                 0.0                         1.0
# 4                                 0.0                         1.0
# ...                               ...                         ...
# 6079                              0.0                         0.0
# 6080                              0.0                         1.0
# 6081                              1.0                         0.0
# 6082                              1.0                         0.0
# 6083                              0.0                         1.0
#
#       remainder__Reviews  remainder__Interviews  remainder__jobs  \
# 0                 2070.0                   14.0              1.0
# ...

# %%
X_train = t.transform(X_train)
X_test = t.transform(X_test)

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_train = pd.DataFrame(X_train,columns=t.get_feature_names_out())
X_test = pd.DataFrame(X_test,columns=t.get_feature_names_out())

# %%
X_train
# Out:
#       Oneh__company_reviews_excellent  Oneh__company_reviews_good  \
# 0                                 1.0                         0.0
# 1                                 0.0                         0.0
# 2                                 0.0                         1.0
# 3                                 1.0                         0.0
# 4                                 1.0                         0.0
# ...                               ...                         ...
# 6079                              0.0                         1.0
# 6080                              0.0                         0.0
# 6081                              1.0                         0.0
# 6082                              0.0                         1.0
# 6083                              0.0                         0.0
#
#       remainder__Reviews  remainder__Interviews  remainder__jobs  \
# 0                 2020.0                   13.0              0.0
# ...

# %%
X_train.isnull().sum()
# Out:
# Oneh__company_reviews_excellent    0
# Oneh__company_reviews_good         0
# remainder__Reviews                 0
# remainder__Interviews              0
# remainder__jobs                    0
# remainder__Benefits                0
# remainder__photos                  0
# dtype: int64

# %%
df
# Out:
#      company_reviews  Reviews  Salaries  Interviews  jobs  Benefits  photos
# 0               good   5440.0    4500.0        48.0  34.0      31.0       6
# 1               Poor   1820.0     895.0         8.0  18.0      15.0       1
# 2               Poor   3230.0    2500.0        40.0  12.0      25.0      25
# 3               good   3850.0    1300.0        26.0  12.0      12.0       0
# 4               good   1080.0     513.0         8.0   0.0       4.0       0
# ...              ...      ...       ...         ...   ...       ...     ...
# 7601            good   1900.0     516.0        18.0   0.0      14.0       1
# 7602            good   2050.0     517.0        21.0   4.0       7.0       2
# 7603            good   1980.0    1200.0        16.0  20.0      13.0       6
# 7604       excellent      1.2    4500.0        66.0   0.0      66.0      20
# 7605       excellent   1460.0     304.0         8.0   0.0       2.0       5
#
# [7606 rows x 7 columns]

# %%
pr = lr.predict(X_test)
# Out:
# c:\Users\acer\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,pr)
# Out:
# 0.9497325806229474
